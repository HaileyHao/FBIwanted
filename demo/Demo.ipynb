# %% [markdown]
# ## Package Installation

# %%
# !pip install -i https://test.pypi.org/simple/ fbiwanted
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: fbiwanted in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (0.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.26.0 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from fbiwanted) (2.26.0)
# Requirement already satisfied: pandas<2.0.0,>=1.3.4 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from fbiwanted) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.4->fbiwanted) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.4->fbiwanted) (2021.3)
# Requirement already satisfied: numpy>=1.20.0 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.4->fbiwanted) (1.21.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from requests<3.0.0,>=2.26.0->fbiwanted) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from requests<3.0.0,>=2.26.0->fbiwanted) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from requests<3.0.0,>=2.26.0->fbiwanted) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from requests<3.0.0,>=2.26.0->fbiwanted) (3.3)
# Requirement already satisfied: six>=1.5 in /Users/hailey/.pyenv/versions/3.9.1/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas<2.0.0,>=1.3.4->fbiwanted) (1.15.0)

# %% [markdown]
# ## import all functions

# %%
from fbiwanted import FBIwanted

# %% [markdown]
# ## Function 1 : fbi_wanted_appearance( )
#
# ### Retrieve FBI wanted people info by appearance.
#
# #### Example: Look for information of FBI wanted people with brown eyes, blond hair and are white.

# %%
FBIwanted.fbi_wanted_appearance(eyes = "brown", hair = "blond", race = "white")
# Out:
# 12 records retrieved.
#                              name status     sex nationality   race   hair  \
# 0               Laura Ann Johnson     na  Female        None  white  blond
# 1                  Debra Kay King     na  Female        None  white  blond
# 2              Simone S. Ridinger     na  Female        None  white  blond
# 3    Aleksey Viktorovich Lukashev     na    Male     Russian  white  blond
# 4                        Jane Doe     na  Female        None  white  blond
# 5    Anna Vladislavovna Bogacheva     na  Female     Russian  white  blond
# 6                 Tamara Ann Haas     na  Female        None  white  blond
# 7   Sergey Vladimirovich Detistov     na    Male     Russian  white  blond
# 8                Kathryn Menendez     na  Female        None  white  blond
# 9            Kristin Denise Smart     na  Female        None  white  blond
# 10                Carla Vicentini     na  Female        None  white  blond
# 11       Pavel Valeryevich Frolov     na    Male     Russian  white  blond
#
#      eyes  height_max  height_min  \
# 0   brown        66.0        66.0
# 1   brown        64.0        64.0
# 2   brown        63.0        62.0
# 3   brown         NaN         NaN
# 4   brown        64.0        64.0
# 5   brown         NaN         NaN
# 6   brown        64.0        64.0
# 7   brown         NaN         NaN
# 8   brown        62.0        62.0
# 9   brown        73.0        73.0
# 10  brown        67.0        67.0
# 11  brown         NaN         NaN
#
#                                       scars_and_marks  dates_of_birth_used  \
# 0   Surgery scar on left forearm\r\nSunburst and b...                 None
# 1   King has a scar on her abdomen and an unknown ...                 None
# 2   Ridinger has a birthmark on her lower back and...                 None
# 3                                                None   [November 7, 1990]
# 4   Moles on the left side of the forehead, tip of...                 None
# 5                                                None     [March 13, 1988]
# 6                                                None     [April 13, 1973]
# 7                                                None      [July 21, 1985]
# 8                                                None                 None
# 9                                                None  [February 20, 1977]
# 10                                               None     [April 29, 1983]
# 11                                               None       [June 7, 1992]
#
#                 place_of_birth  \
# 0                         None
# 1                         None
# 2                         None
# 3   Murmanskaya Oblast, Russia
# 4                         None
# 5            Stavropol, Russia
# 6                         None
# 7        Rostov-On-Don, Russia
# 8                         None
# 9                         None
# 10                      Brazil
# 11              Kaluga, Russia
#
#                                           occupations languages  \
# 0   Officer in the Russian Federation’s Main Intel...      None
# 1   Officer in the Russian Federation's Main Intel...      None
# 2   Officer in the Russian Federation's Main Intel...      None
# 3                                                 NaN      None
# 4                                                 NaN      None
# 5                                                 NaN      None
# 6                                                 NaN      None
# 7                                                 NaN      None
# 8                                                 NaN      None
# 9                                                 NaN      None
# 10                                                NaN      None
# 11                                                NaN      None
#
#                          aliases                         subjects  \
# 0     Лукашев Алексей Викторович            ViCAP Missing Persons
# 1                        Anna V.            ViCAP Missing Persons
# 2                        "Tammy"            ViCAP Missing Persons
# 3   Сергей Владимирович Детистов              Cyber's Most Wanted
# 4        Павел Валерьевич Фролов       ViCAP Unidentified Persons
# 5                            NaN              Counterintelligence
# 6                            NaN              Seeking Information
# 7                            NaN              Cyber's Most Wanted
# 8                            NaN              Seeking Information
# 9                            NaN  Kidnappings and Missing Persons
# 10                           NaN  Kidnappings and Missing Persons
# 11                           NaN              Cyber's Most Wanted
#
#    field_offices                                                url  \
# 0   washingtondc  https://www.fbi.gov/wanted/vicap/missing-perso...
# 1    minneapolis  https://www.fbi.gov/wanted/vicap/missing-perso...
# 2     pittsburgh  https://www.fbi.gov/wanted/vicap/missing-perso...
# 3     losangeles  https://www.fbi.gov/wanted/cyber/aleksey-vikto...
# 4         newark  https://www.fbi.gov/wanted/vicap/unidentified-...
# 5            NaN  https://www.fbi.gov/wanted/counterintelligence...
# 6            NaN  https://www.fbi.gov/wanted/seeking-info/tammy-...
# 7            NaN  https://www.fbi.gov/wanted/cyber/sergey-vladim...
# 8            NaN  https://www.fbi.gov/wanted/seeking-info/kathry...
# 9            NaN  https://www.fbi.gov/wanted/kidnap/kristin-deni...
# 10           NaN  https://www.fbi.gov/wanted/kidnap/carla-vicentini
# 11           NaN  https://www.fbi.gov/wanted/cyber/pavel-valerye...
#
#     reward_max                                    warning_message
# 0            0                                               None
# 1            0                                               None
# 2            0                                               None
# 3            0  SHOULD BE CONSIDERED ARMED AND DANGEROUS, AN I...
# 4            0                                               None
# 5            0  SHOULD BE CONSIDERED AN INTERNATIONAL FLIGHT RISK
# 6            0                                               None
# 7            0  SHOULD BE CONSIDERED ARMED AND DANGEROUS, AN I...
# 8            0                                               None
# 9            0                                               None
# 10       99999                                               None
# 11           0  SHOULD BE CONSIDERED ARMED AND DANGEROUS, AN I...

# %% [markdown]
# ## Function 2  : fbi_wanted_office( )
#
# ### Retrieve FBI wanted people info by administrative region (city name).
#
# #### Example: Look for information of people wanted by the Honolulu FBI office.

# %%
FBIwanted.fbi_wanted_office(field_offices = "honolulu")
# Out:
# 5 records retrieved.
#                            name status     sex nationality   race   hair  \
# 0  Julieanne Baldueza Dimitrion     na  Female    American  asian  black
# 1        John Michael Dimitrion     na    Male    American   None  black
# 2                  Maleina Luhk     na  Female    American  asian  brown
# 3                   Faloma Luhk     na  Female    American  asian  brown
# 4              Raddulan Sahiron     na    Male    Filipino  asian   gray
#
#     eyes  height_max  height_min  \
# 0  brown          59          59
# 1  brown          67          67
# 2  brown          48          48
# 3  brown          61          61
# 4  black          66          66
#
#                                      scars_and_marks  dates_of_birth_used  \
# 0                                         None known     [March 22, 1972]
# 1                                         None known     [April 12, 1976]
# 2         Maleina has a birthmark on her left cheek.  [February 13, 2002]
# 3                                               None   [February 9, 2001]
# 4  Sahiron's right arm is amputated above his elbow.                 None
#
#                              place_of_birth occupations         languages  \
# 0                             Massachusetts   [Unknown]              None
# 1                                    Hawaii   [Unknown]              None
# 2          Saipan, Northern Mariana Islands        None              None
# 3          Saipan, Northern Mariana Islands        None              None
# 4  Kabbun Takas, Patikul, Jolo, Philippines        None  [Tausug, Arabic]
#
#                                              aliases  \
# 0                    [Julie Anne Baldueza Dimitrion]
# 1                [John M. Dimitrion, John Dela Cruz]
# 2                                               None
# 3                                               None
# 4  [Radullan Sahiron, Radulan Sahiron, Raddulan S...
#
#                           subjects field_offices  \
# 0               White-Collar Crime      honolulu
# 1               White-Collar Crime      honolulu
# 2  Kidnappings and Missing Persons      honolulu
# 3  Kidnappings and Missing Persons      honolulu
# 4           Most Wanted Terrorists      honolulu
#
#                                                  url  reward_max  \
# 0  https://www.fbi.gov/wanted/wcc/julieanne-baldu...       10000
# 1  https://www.fbi.gov/wanted/wcc/john-michael-di...       10000
# 2     https://www.fbi.gov/wanted/kidnap/maleina-luhk           0
# 3      https://www.fbi.gov/wanted/kidnap/faloma-luhk           0
# 4  https://www.fbi.gov/wanted/wanted_terrorists/r...           0
#
#                             warning_message
# 0                                      None
# 1                                      None
# 2                                      None
# 3                                      None
# 4  SHOULD BE CONSIDERED ARMED AND DANGEROUS

# %% [markdown]
# ## Function 3  : fbi_poster_appearance( )
#
# ### Download posters of FBI wanted people by appearence.
#
# #### Example: Download posters of FBI wanted people with black eyes and black hair.

# %%
# example:
FBIwanted.fbi_poster_appearance(eyes = "black", hair = "black")
# Out:
# Download completed. 10 posters downloaded.
